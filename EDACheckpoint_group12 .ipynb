# %% [markdown]
# **If you lost points on the last checkpoint you can get them back by responding to TA/IA feedback**
#
# Update/change the relevant sections where you lost those points, make sure you respond on GitHub Issues to your TA/IA to call their attention to the changes you made here.
#
# Please update your Timeline... no battle plan survives contact with the enemy, so make sure we understand how your plans have changed.

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Sadaf Jamali-Hanjani
# - Emilie Joseph
# - Raisa Shafi
# - Janhavi Shah
# - Austria Wang

# %% [markdown]
# # Research Question

# %% [markdown]
# How do the marriage and divorce rates in the United States impact the financial success of romantic comedies spanning from 1990 to 2022? Specifically, is there a discernible trend in the profitability, measured by a 20% profit margin compared to the film's original budget, of movies falling under the genre of romantic comedies, identified by keywords such as 'romance', 'love', 'fate', 'humor', 'meet cute', 'chemistry', 'heartwarming', 'feel good', 'relationships', and 'laughter' across different decades?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Marriage and divorce rates in the United States have long been subjects of interest, not only for sociologists and demographers but also for those in the entertainment industry. The portrayal of romantic relationships in films, particularly romantic comedies, often reflects societal norms, values, and attitudes towards love and marriage. Understanding the fluctuations in marriage and divorce rates can provide insights into how these changes might influence the themes, narratives, and ultimately, the financial success of romantic comedies.
#
# Several studies have explored the relationship between societal trends, including marriage and divorce rates, and their impact on media content. For instance, research by Banjo (2002) suggests that media consumption, especially of romanticized content, can foster unrealistic expectations and perceptions about romantic relationships, potentially influencing individuals' attitudes and behaviors in their own relationships<sup>[1]</sup>.
#
# Ray (2022) highlights the concept of relational schemas, which are cognitive representations of how individuals expect relationships to function. The influence of romantic movie media on the development of these schemas suggests that individuals with high exposure to such media may internalize and seek to replicate the relationship patterns depicted in films<sup>[3]</sup>. Larson's (1988) adds onto this by stating that when individuals consume romantic comedies, they are often presented with idealized depictions of romantic partners who effortlessly embody multiple roles and fulfill all relationship needs. This can further perpetuate unrealistic expectations within viewers' own relationships, potentially leading to dissatisfaction or disillusionment when reality fails to meet the standards set by media portrayals, and eventually divorce<sup>[2]</sup>. However, while these studies provide valuable insights into the individual components of romantic comedies and societal trends, there is a gap in research specifically examining the intersection between marriage and divorce rates and the financial success of romantic comedies over time.
#
# In this study, we aim to fill this gap by analyzing the profitability of romantic comedies spanning from 1990 to 2022 in relation to fluctuations in marriage and divorce rates in the United States. By identifying keywords associated with romantic comedies and using box office data to measure profitability, we seek to uncover any discernible trends or correlations between societal relationship dynamics and the commercial success of romantic comedies. This analysis will contribute to a deeper understanding of how societal changes impact media consumption patterns and the financial performance of films within the romantic comedy genre.
#
# <sub>References:</sub>
#
# <sub>[1] - Banjo, O. (n.d.). (PDF) the effect of media consumption on the perception of romantic relationships. https://www.researchgate.net/publication/283703576_The_Effect_of_Media_Consumption_on_the_Perception_of_Romantic_Relationships</sub>
#
# <sub>[2] - Larson, J. H. (1988). The interplay of marriage and friendship. In W. H. Jones & D. Perlman (Eds.), Advances in personal relationships (Vol. 1, pp. 277–311). Jessica Kingsley Publishers.</sub>
#
# <sub>[3] - Ray, C. R. (n.d.). (thesis). Romantic media exposure’s effect on relationship beliefs and expectations. </sub>

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Our team's hypothesis explores the relationship between the financial success of romantic comedies and divorce and marriage rates from 1990 to 2022. Our prediction is that an increase in divorce rates will lower the financial success of romantic comedies, if there is a decrease in divorce rates and an increase in marriages the profitability will be higher. To identify the success of romantic comedies we will measure a 20% profit margin over the film's original budget. For our divorce and marriage data, we will use information from the CDC, 1990 to 2022 divorce and marriage rates which are organized by state. This helps us understand what influence divorce and marriage have on the financial success of romantic comedies.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: TMDB 5000 Movie Dataset
#   - Link to the dataset:https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata
#   - Number of observations: 1034416
#   - Number of variables: 24
#
# - Dataset #2
#   - Dataset Name: Marriage Rate by State in the United States from 1990-2022
#   - Link to the dataset: https://www.cdc.gov/nchs/data/dvs/marriage-divorce/state-marriage-rates-90-95-00-22.pdf
#   - Number of observations: 51
#   - Number of variables: 26
#
# - Dataset #3
#   - Dataset Name: Divorce Rate by State in the United States from 1990-2022
#   - Link to the dataset: https://www.cdc.gov/nchs/data/dvs/marriage-divorce/state-divorce-rates-90-95-00-22.pdf
#   - Number of observations: 51
#   - Number of variables: 26
#
# The TMDB Movies Dataset features top grossing romantic comedy movies from 1990 to 2022. We will be looking at features such as MPAA ratings, total gross profit, inflation-adjusted gross profits, tickets sold, market share, and gross profits by the year. We are also using the dataset to extract variables such as keywords, taglines, budget, revenue, release date and genre to compare to the Marriage and Divorce Datasets.
#
# The Centers for Disease Control and Prevention have released a list for the Change in the Reporting of Marriage and Divorce Statistics. This dataset takes a look at information of the rates of divorces and marriages at both the national and state levels. Tracking data from year 1990 until 2022, we can break down important trends such as the percentage of divorces and marriages, by state, year, and by population.
#
# We plan to analyze trends between popular romantic comedy gross profits and prevalence over the past 2 decades, along the USA’s marriage and divorce rate trends to see if there is a relationship between the success of romantic comedies based on the populations of people that have been married or divorces. All three of our datasets will be used to see if we can find a trend line between the question that we are proposing.

# %% [markdown]
# ## The Movie Database

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# max       10.000000  13752.000000

# %%
movies.drop_duplicates(inplace=True)
movies.drop(columns=['id', 'status','spoken_languages','production_countries','homepage','production_companies','original_language','original_title','popularity'], inplace=True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   budget        4803 non-null   int64
#  1   genres        4803 non-null   object
#  2   keywords      4803 non-null   object
#  3   overview      4800 non-null   object
#  4   release_date  4802 non-null   object
#  5   revenue       4803 non-null   int64
#  6   runtime       4801 non-null   float64
#  7   tagline       3959 non-null   object
#  8   title         4803 non-null   object
#  9   vote_average  4803 non-null   float64
#  10  vote_count    4803 non-null   int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 412.9+ KB

# %% [markdown]
# ## Marriage Rate in the United States from 1990-2022

# %%
marriage = pd.read_csv('state-marriage-rates.csv')
marriage = marriage.melt(id_vars=['State'],var_name= 'Year', value_name='Marriage Rate')
marriage.head()
# Out:
#         State  Year Marriage Rate
# 0     Alabama  2022           7.3
# 1      Alaska  2022           6.5
# 2     Arizona  2022           5.8
# 3    Arkansas  2022           7.9
# 4  California  2022           5.7

# %%
marriage.describe()
# Out:
#           State  Year  Marriage Rate
# count      1275  1275         1275.0
# unique       51    25          202.0
# top     Alabama  2022            7.3
# freq         25    51           34.0

# %% [markdown]
# ## Divorce Rate in the United States from 1990-2022 in the United States from 1990-2022

# %%
divorce = pd.read_csv('state-divorce-rates.csv')
divorce = divorce.melt(id_vars=['State'],var_name= 'Year', value_name='Divorce Rate')
divorce.head()
# Out:
#         State  Year Divorce Rate
# 0     Alabama  2022          3.2
# 1      Alaska  2022            3
# 2     Arizona  2022          2.3
# 3    Arkansas  2022          3.5
# 4  California  2022          ---

# %%
divorce.describe()
# Out:
#           State  Year Divorce Rate
# count      1275  1275         1275
# unique       51    25           71
# top     Alabama  2022          ---
# freq         25    51          125

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# ### The Top "Love-Themed/Romantic" Movie Each Year During 1990-2022 by Budget and Revenue
#
# For this analysis, we chose to show the relationship between movies with the keyword tag of 'love' to their respective budgets and revenue. We only wanted to see the top grossing films related to 'love' during 1990 to 2022 to correspond with our marriage and divorce datasets. We chose to use the keyword 'love' instead of the genre 'romance' due to the major overlap in movies that were not related to 'romantic' movies but rather movies with 'romantic' elements in it. We wanted to focus on analyzing movies that were 'love' centered which is why we condensed our dataset to fit this specific category.
#
# We chose to pull out each movie's budget and revenue to show the financial incentive movie studios have when deciding to make 'love' themed movies. We also decided to use a bar graph to compare the budget to the revenue to show how financially successful each movie was during 1990-2022.
#
# From 1990-1999, James Cameron's 1997 movie "Titanic" was able to make 10x their original budget grossing over 2.2 billion dollars in revenue with a budget of 200 million dollars. "Titanic" was an extreme outlier when it came to 'love' themed movies in this decade. The second highest earning film was Disney's 1994 movie "The Lion King" grossing over 968 million dollars with a budget of 45 million dollars.
#
# From 2000-2009 we saw more 'action' based films with elements of 'romance' and 'love' rather than films that were solely made with the intention of romance being the central theme. The 2007 movie "Pirates of the Caribbean: At World's End" had the highest revenue with "Harry Potter and the Half Blood Price" in 2009 following closely behind. This decade seemed to have movies with a higher budget compared to the 90s and 2010 onwards.
#
# From 2010-2019, there was a lull in revenue related to 'love' themed movies as four out of ten movies were not able to make back their original budget. The movies "R.I.P.D" (2013), "Aloha" (2015), "Live by Night" (2016), and "The Space Between Us" (2017) all were not able to break even as the movie studios lost money rather than gain a profit for producing these films.
#
# From 2020-2022, the lowest grossing film was in 2020 with Thomas Bezucha's "Let Him Go". There could have been many different factors in why this movie wasn't able to make back its original budget as this was the year a global pandemic affected the world as well as film industry. Bouncing back in 2021 and 2022, with "Spiderman: No Way Home" in 2021 grossing 1.9 billion dollars and "Avatar: The Way of Water" in 2022 grossing 2.3 billion dollars. Both of these movies were sequels which could have also attributed to this increase in revenue and audience reception.
#
# Overall this graph shows that movies with ‘love’ themes are able to make the movie studios money even if the budget is over 100 million dollars and that movies that were the most financially lucrative were movies that were ‘action’ based with ‘love’ elements. Outliers such as “Titanic” and “Avatar: The Way of Water” shows that movie goers are willing to watch movies that are ‘romance’ based with an added element of ‘action’.

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')


love = movies[movies['keywords'].str.contains('love', case=False, na=False)].copy()
love['release_year'] = pd.to_datetime(love['release_date'], errors='coerce').dt.year
love = love[(love['release_year'] >= 1990) & (love['release_year'] <= 2022)]
love = love.dropna(subset=['budget', 'revenue'])
love = love[(love['budget'] != 0) & (love['revenue'] != 0)]
love['budget'] = love['budget'].replace('[\$,]', '', regex=True).astype(float)
love['revenue'] = love['revenue'].replace('[\$,]', '', regex=True).astype(float)

top_lovemovies = love.loc[love.groupby('release_year')['budget'].idxmax()]

plt.rcParams.update({'font.size': 30})
plt.figure(figsize=(30, 30))
plt.rcParams.update({
    'font.size': 30,
    'axes.titlesize': 40,
    'axes.labelsize': 30,
    'xtick.labelsize': 30,
    'ytick.labelsize': 30,
    'legend.fontsize': 30
})

bar_width = 0.4
plt.bar(top_lovemovies['release_year'] - bar_width / 2, top_lovemovies['budget'], bar_width, color='plum', label='Budget')
plt.bar(top_lovemovies['release_year'] + bar_width / 2, top_lovemovies['revenue'], bar_width, color='hotpink', label='Revenue')
plt.xlabel('Year')
plt.ylabel('Amount on Dollars (In Billions)')
plt.title('The Top "Love-Themed/Romantic" Movie Each Year During 1990-2022 by Budget and Revenue')

for i, row in top_lovemovies.iterrows():
    plt.text(row['release_year'] - bar_width / 2, row['budget'], row['title'], ha='center', va='bottom', rotation=90)


plt.xticks(top_lovemovies['release_year'], rotation=45)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### State with the Highest Marriage Rate
# For this portion of the analysis we looked at the highest marriage rate from every year to figure out which state, if any, had the highest marriage rate.

# %%
## YOUR CODE HERE
highest_marriage_rate_per_year = marriage.loc[marriage.groupby('Year')['Marriage Rate'].idxmax()]
highest_marriage_rate_per_year = highest_marriage_rate_per_year.rename(columns={'Marriage Rate':'Highest Marriage Rate'})
highest_marriage_rate_per_year
# Out:
#                State  Year Highest Marriage Rate
# 1252          Nevada  1990                  99.0
# 1201          Nevada  1995                  85.2
# 1139        Kentucky  2000                   9.8
# 1111  South Carolina  2001                   9.9
# 1020         Alabama  2002                   9.9
# 1014         Vermont  2003                   9.7
# 946           Nevada  2004                  62.1
# 895           Nevada  2005                  57.4
# 866          Wyoming  2006                   9.3
# 793           Nevada  2007                  48.6
# 742           Nevada  2008                  42.3
# 691           Nevada  2009                  40.3
# 640           Nevada  2010                  38.3
# 589           Nevada  2011                  36.9
# 538           Nevada  2012                  35.1
# 462         Arkansas  2013                   9.8
# 453          Vermont  2014                   8.7
# 385           Nevada  2015                  31.0
# 334           Nevada  2016                  28.4
# 283           Nevada  2017                  28.6
# 232           Nevada  2018                  26.7
# 181           Nevada  2019                  25.9
# 130           Nevada  2020                  21.0
# 79            Nevada  2021                  26.2
# 28            Nevada  2022                  25.9

# %% [markdown]
# Using the marriage data, we were able to identify the highest marriage rate from each year between 1990 to 2022 (except for 1991-1994). Looking at the data above, we can see that Nevada has had the highest marriage rate for a considerable number of times over the years. To be sure, we looked at the value counts for each state:

# %%
state_with_highest_marriage_rate = highest_marriage_rate_per_year['State'].value_counts()
state_with_highest_marriage_rate
# Out:
# State
# Nevada            18
# Vermont            2
# Kentucky           1
# South Carolina     1
# Alabama            1
# Wyoming            1
# Arkansas           1
# Name: count, dtype: int64

# %% [markdown]
# We can see from the value counts that Nevada has had the highest marriage rate for 18 out of the 25 years we are observing.

# %%
plt.rcParams.update({'font.size': 50})
plt.figure(figsize=(18, 7))
plt.rcParams.update({
    'font.size': 30,
    'axes.titlesize': 35,
    'axes.labelsize': 30,
    'xtick.labelsize': 25,
    'ytick.labelsize': 25,
})
state_count1 = state_with_highest_marriage_rate.index
sns.countplot(x='State', data = highest_marriage_rate_per_year, order=state_count1, palette = "rocket")
plt.title('State with the Highest Marriage Rate')
plt.ylabel('Count')
plt.xlabel('State')
plt.xticks(rotation=45)
ms = plt.gcf()

# %% [markdown]
# From the graph above, we can see that Nevada has had the highest marriage rate more times than any other state by a large amount.

# %% [markdown]
# ### State with the Highest Divorce Rate
#
# Similar to the marriage rates, we looked at the highest divorce rate from every year to figure out which state had the highest divorce rate overall.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
highest_divorce_rate_per_year = divorce.loc[divorce.groupby('Year')['Divorce Rate'].idxmax()]
highest_divorce_rate_per_year = highest_divorce_rate_per_year.rename(columns={'Divorce Rate':'Highest Divorce Rate'})
highest_divorce_rate_per_year
# Out:
#          State  Year Highest Divorce Rate
# 1260  Oklahoma  1990                  7.7
# 1201    Nevada  1995                  7.8
# 1150    Nevada  2000                  9.9
# 1099    Nevada  2001                  6.3
# 1048    Nevada  2002                  7.1
# 997     Nevada  2003                  7.3
# 946     Nevada  2004                  6.3
# 895     Nevada  2005                  7.4
# 844     Nevada  2006                  6.7
# 793     Nevada  2007                  6.4
# 742     Nevada  2008                  6.4
# 691     Nevada  2009                  6.6
# 640     Nevada  2010                  5.9
# 589     Nevada  2011                  5.6
# 538     Nevada  2012                  5.5
# 487     Nevada  2013                  5.1
# 436     Nevada  2014                  5.3
# 360   Arkansas  2015                  4.8
# 342   Oklahoma  2016                  4.4
# 283     Nevada  2017                  4.5
# 232     Nevada  2018                  4.4
# 181     Nevada  2019                  4.2
# 152    Wyoming  2020                  3.8
# 79      Nevada  2021                  4.2
# 28      Nevada  2022                  4.2

# %% [markdown]
# From the divorce dataset, we were able to get the highest divorce rate from each year between 1990 to 2022 (except for 1991-1994). Like the marriage rate data, we can see that Nevada has had the highest divorce rate for a large number of times over the years as well. Again, we looked at the value counts for each state to confirm:

# %%
state_with_highest_divorce_rate = highest_divorce_rate_per_year['State'].value_counts()
state_with_highest_divorce_rate
# Out:
# State
# Nevada      21
# Oklahoma     2
# Arkansas     1
# Wyoming      1
# Name: count, dtype: int64

# %% [markdown]
# We can see from the value counts that Nevada has had the highest marriage rate for 21 out of the 25 years we are observing.

# %%
plt.rcParams.update({'font.size': 50})
plt.figure(figsize=(22, 13))
plt.rcParams.update({
    'font.size': 40,
    'axes.titlesize': 50,
    'axes.labelsize': 40,
    'xtick.labelsize': 30,
    'ytick.labelsize': 30,
})
state_count2 = state_with_highest_divorce_rate.index
sns.countplot(x='State', data = highest_divorce_rate_per_year, order=state_count2, palette = "mako")
plt.title('State with the Highest Divorce Rate')
plt.ylabel('Count')
plt.xlabel('State')
plt.xticks(rotation=45)
ds = plt.gcf()

# %% [markdown]
# From the graph above, we can see that Nevada has had the highest divorce rate more times than any other state by a large amount as well.

# %% [markdown]
# ### Vote Count in "Love" Movies
#
# By grouping the classified 'love' movies found from our TMDB dataset, we are able to identify which movies were chosen by the audience as the best movies.
#
# In the 1990s there seemed to have been a general trend of these 'love' themed movies to be overall unfavored when compared to the early 2000s
#
# But, there are some staple movies such as the 'Titanic' and 'Forest Gump', which have a high amount of votes.
#
# In the later 2000s, some fantasy movies such as 'Avatar' and 'Inception' have been rated very high.
#
# These trends could infer that romantic or love themed movies may have not been all the popular or favored much around the later 2000s.

# %%
popular_lovemovies = love.loc[love.groupby('release_year')['vote_count'].idxmax()]
popular_lovemovies
# Out:
#            budget                                             genres  \
# 2108   20000000.0  [{"id": 14, "name": "Fantasy"}, {"id": 18, "na...
# 1967   24000000.0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 1695   28000000.0  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 2790   12500000.0  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 809    55000000.0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 556    72000000.0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 2661   14500000.0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 25    200000000.0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 407    90000000.0  [{"id": 14, "name": "Fantasy"}, {"id": 18, "na...
# 1120   42000000.0  [{"id": 10749, "name": "Romance"}, {"id": 35, ...
# 213   125000000.0  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 1260   10000000.0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 159   139000000.0  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 423    80000000.0  [{"id": 14, "name": "Fantasy"}, {"id": 35, "na...
# 30    200000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 119   150000000.0  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 2465   19000000.0  [{"id": 14, "name": "Fantasy"}, {"id": 18, "na...
# 113   150000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 1337   37000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 0     237000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 96    160000000.0  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 69    170000000.0  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 903    50000000.0  [{"id": 35, "name": "Comedy"}, {"id": 14, "nam...
# 506    76000000.0  [{"id": 16, "name": "Animation"}, {"id": 35, "...
# 2838   12000000.0  [{"id": 10749, "name": "Romance"}, {"id": 18, ...
# 1599   25000000.0  [{"id": 14, "name": "Fantasy"}, {"id": 18, "na...
#
#                                                homepage      id  \
# 2108                                                NaN     162
# 1967                                                NaN     177
# 1695                   http://movies.disney.com/aladdin     812
# 2790                                                NaN     319
# 809                                                 NaN      13
# 556                                                 NaN     197
# 2661                     http://www.romeoandjuliet.com/     454
# 25                          http://www.titanicmovie.com     597
# 407                        http://www.meetjoeblack.com/     297
# 1120                       http://www.notting-hill.com/     509
# 213                   http://www.missionimpossible.com/     955
# 1260       http://www.die-fabelhafte-welt-der-amelie.de     194
# 159      http://www.sonypictures.com/movies/spider-man/     557
# 423                       http://www.brucealmighty.com/     310
# 30      http://www.sonypictures.com/movies/spider-man2/     558
# 119   http://www2.warnerbros.com/batmanbegins/index....     272
# 2465                       http://www.panslabyrinth.com    1417
# 113        http://www.harrypotterorderofthephoenix.com/     675
# 1337                    http://www.twilightthemovie.com    8966
# 0                           http://www.avatarmovie.com/   19995
# 96                http://inceptionmovie.warnerbros.com/   27205
# 69                            http://www.hugomovie.com/   44826
# 903                           http://www.tedisreal.com/   72105
# 506                        http://www.despicableme.com/   93456
# 2838                                                NaN  222935
# 1599                    http://theageofadalinemovie.com  293863
#
#                                                keywords original_language  \
# 2108  [{"id": 240, "name": "underdog"}, {"id": 699, ...                en
# 1967  [{"id": 113, "name": "holy grail"}, {"id": 960...                en
# 1695  [{"id": 2343, "name": "magic"}, {"id": 4344, "...                en
# 2790  [{"id": 494, "name": "father son relationship"...                en
# 809   [{"id": 422, "name": "vietnam veteran"}, {"id"...                en
# 556   [{"id": 30, "name": "individual"}, {"id": 388,...                en
# 2661  [{"id": 497, "name": "shakespeare"}, {"id": 36...                en
# 25    [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 407   [{"id": 314, "name": "life and death"}, {"id":...                en
# 1120  [{"id": 212, "name": "london england"}, {"id":...                en
# 213   [{"id": 321, "name": "terror"}, {"id": 514, "n...                en
# 1260  [{"id": 90, "name": "paris"}, {"id": 128, "nam...                fr
# 159   [{"id": 1014, "name": "loss of lover"}, {"id":...                en
# 423   [{"id": 186, "name": "christianity"}, {"id": 3...                en
# 30    [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 119   [{"id": 486, "name": "himalaya"}, {"id": 779, ...                en
# 2465  [{"id": 514, "name": "spain"}, {"id": 836, "na...                es
# 113   [{"id": 530, "name": "prophecy"}, {"id": 616, ...                en
# 1337  [{"id": 815, "name": "soulmates"}, {"id": 3133...                en
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 96    [{"id": 1014, "name": "loss of lover"}, {"id":...                en
# 69    [{"id": 295, "name": "library"}, {"id": 1507, ...                en
# 903   [{"id": 6054, "name": "friendship"}, {"id": 96...                en
# 506   [{"id": 4289, "name": "secret agent"}, {"id": ...                en
# 2838  [{"id": 587, "name": "amsterdam"}, {"id": 818,...                en
# 1599  [{"id": 582, "name": "san francisco"}, {"id": ...                en
#
#                                  original_title  \
# 2108                        Edward Scissorhands
# 1967                            The Fisher King
# 1695                                    Aladdin
# 2790                               True Romance
# 809                                Forrest Gump
# 556                                  Braveheart
# 2661                             Romeo + Juliet
# 25                                      Titanic
# 407                              Meet Joe Black
# 1120                               Notting Hill
# 213                      Mission: Impossible II
# 1260        Le fabuleux destin d'Amélie Poulain
# 159                                  Spider-Man
# 423                              Bruce Almighty
# 30                                 Spider-Man 2
# 119                               Batman Begins
# 2465                     El laberinto del fauno
# 113   Harry Potter and the Order of the Phoenix
# 1337                                   Twilight
# 0                                        Avatar
# 96                                    Inception
# 69                                         Hugo
# 903                                         Ted
# 506                             Despicable Me 2
# 2838                     The Fault in Our Stars
# 1599                         The Age of Adaline
#
#                                                overview  popularity  \
# 2108  A small suburban town receives a visit from a ...   47.513630
# 1967  Two troubled men face their terrible destinies...   16.146572
# 1695  Princess Jasmine grows tired of being forced t...   92.982009
# 2790  Clarence marries hooker Alabama, steals cocain...   35.268557
# 809   A man with a low IQ has accomplished great thi...  138.133331
# 556   Enraged at the slaughter of Murron, his new br...   60.722162
# 2661  In director Baz Luhrmann's contemporary take o...   41.493042
# 25    84 years later, a 101-year-old woman named Ros...  100.025899
# 407   When the grim reaper comes to collect the soul...   36.069611
# 1120  The British comedy from director Roger Michell...   28.969151
# 213   With computer genius Luther Stickell at his si...   54.931334
# 1260  At a tiny Parisian café, the adorable yet pain...   73.720244
# 159   After being bitten by a genetically altered sp...   82.502566
# 423   Bruce Nolan toils as a "human interest" televi...  109.684788
# 30    Peter Parker is going through a major identity...   35.149586
# 119   Driven by tragedy, billionaire Bruce Wayne ded...  115.040024
# 2465  Living with her tyrannical stepfather in a new...   90.809408
# 113   Returning for his fifth year of study at Hogwa...   78.144395
# 1337  When Bella Swan moves to a small town in the P...  127.084938
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 96    Cobb, a skilled thief who commits corporate es...  167.583710
# 69    Hugo is an orphan boy living in the walls of a...   32.319043
# 903   John Bennett, a man whose childhood wish of br...   68.876910
# 506   Gru is recruited by the Anti-Villain League to...  136.886704
# 2838  Despite the tumor-shrinking medical miracle th...   74.358971
# 1599  After 29-year-old Adaline recovers from a near...   82.052056
#
#                                    production_companies  ... release_date  \
# 2108  [{"name": "Twentieth Century Fox Film Corporat...  ...   1990-12-05
# 1967          [{"name": "TriStar Pictures", "id": 559}]  ...   1991-09-09
# 1695        [{"name": "Walt Disney Pictures", "id": 2}]  ...   1992-11-25
# 2790  [{"name": "Davis-Films", "id": 342}, {"name": ...  ...   1993-09-09
# 809           [{"name": "Paramount Pictures", "id": 4}]  ...   1994-07-06
# 556   [{"name": "Icon Entertainment International", ...  ...   1995-05-24
# 2661  [{"name": "Bazmark Films", "id": 240}, {"name"...  ...   1996-10-31
# 25    [{"name": "Paramount Pictures", "id": 4}, {"na...  ...   1997-11-18
# 407   [{"name": "Universal Pictures", "id": 33}, {"n...  ...   1998-11-12
# 1120  [{"name": "Bookshop Productions", "id": 282}, ...  ...   1999-05-13
# 213   [{"name": "Paramount Pictures", "id": 4}, {"na...  ...   2000-05-24
# 1260  [{"name": "France 3 Cin\u00e9ma", "id": 591}, ...  ...   2001-04-25
# 159   [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   2002-05-01
# 423   [{"name": "Universal Pictures", "id": 33}, {"n...  ...   2003-05-23
# 30    [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   2004-06-25
# 119   [{"name": "DC Comics", "id": 429}, {"name": "L...  ...   2005-06-10
# 2465  [{"name": "Estudios Picasso", "id": 2029}, {"n...  ...   2006-05-27
# 113   [{"name": "Warner Bros.", "id": 6194}, {"name"...  ...   2007-06-28
# 1337  [{"name": "Summit Entertainment", "id": 491}, ...  ...   2008-11-20
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   2009-12-10
# 96    [{"name": "Legendary Pictures", "id": 923}, {"...  ...   2010-07-14
# 69    [{"name": "Paramount Pictures", "id": 4}, {"na...  ...   2011-11-22
# 903   [{"name": "Universal Pictures", "id": 33}, {"n...  ...   2012-06-29
# 506   [{"name": "Universal Pictures", "id": 33}, {"n...  ...   2013-06-25
# 2838  [{"name": "Fox 2000 Pictures", "id": 711}, {"n...  ...   2014-05-16
# 1599  [{"name": "Lakeshore Entertainment", "id": 126...  ...   2015-04-16
#
#            revenue  runtime  \
# 2108  5.300000e+07    105.0
# 1967  4.189549e+07    137.0
# 1695  5.040502e+08     90.0
# 2790  1.228155e+07    120.0
# 809   6.779454e+08    142.0
# 556   2.100000e+08    177.0
# 2661  1.472988e+08    120.0
# 25    1.845034e+09    194.0
# 407   1.429401e+08    178.0
# 1120  3.638897e+08    124.0
# 213   5.463881e+08    123.0
# 1260  1.739220e+08    122.0
# 159   8.217086e+08    121.0
# 423   4.845728e+08    101.0
# 30    7.837663e+08    127.0
# 119   3.742187e+08    140.0
# 2465  8.325823e+07    118.0
# 113   9.382127e+08    138.0
# 1337  3.926166e+08    122.0
# 0     2.787965e+09    162.0
# 96    8.255328e+08    148.0
# 69    1.857702e+08    126.0
# 903   5.493683e+08    106.0
# 506   9.707619e+08     98.0
# 2838  3.071668e+08    125.0
# 1599  6.566328e+07    112.0
#
#                                        spoken_languages    status  \
# 2108           [{"iso_639_1": "en", "name": "English"}]  Released
# 1967           [{"iso_639_1": "en", "name": "English"}]  Released
# 1695           [{"iso_639_1": "en", "name": "English"}]  Released
# 2790  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 809            [{"iso_639_1": "en", "name": "English"}]  Released
# 556   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 2661           [{"iso_639_1": "en", "name": "English"}]  Released
# 25    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 407            [{"iso_639_1": "en", "name": "English"}]  Released
# 1120  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 213            [{"iso_639_1": "en", "name": "English"}]  Released
# 1260  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 159            [{"iso_639_1": "en", "name": "English"}]  Released
# 423            [{"iso_639_1": "en", "name": "English"}]  Released
# 30    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 119   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 2465      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 113            [{"iso_639_1": "en", "name": "English"}]  Released
# 1337           [{"iso_639_1": "en", "name": "English"}]  Released
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 96    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 69             [{"iso_639_1": "en", "name": "English"}]  Released
# 903            [{"iso_639_1": "en", "name": "English"}]  Released
# 506            [{"iso_639_1": "en", "name": "English"}]  Released
# 2838           [{"iso_639_1": "en", "name": "English"}]  Released
# 1599           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 2108                                His scars run deep.
# 1967  A Modern Day Tale About The Search For Love, S...
# 1695                                      Wish granted!
# 2790  Stealing, Cheating, Killing. Who said romance ...
# 809   The world will never be the same, once you've ...
# 556          Every man dies. Not every man truly lives.
# 2661             My only love sprung from my only hate.
# 25            Nothing on Earth could come between them.
# 407                      Sooner or later everyone does.
# 1120  Can the most famous film star in the world fal...
# 213                        Expect the impossible again.
# 1260           One person can change your life forever.
# 159        With great power comes great responsibility.
# 423                                   In Bruce we trust
# 30                         There's a hero in all of us.
# 119                              Evil fears the knight.
# 2465  What happens when make-believe believes it's r...
# 113                            Evil Must Be Confronted.
# 1337   When you can live forever, what do you live for?
# 0                           Enter the World of Pandora.
# 96                 Your mind is the scene of the crime.
# 69    One of the most legendary directors of our tim...
# 903                                      Ted is coming.
# 506                                         Back 2 Work
# 2838                                One Sick Love Story
# 1599                                  Love is timeless.
#
#                                           title vote_average  vote_count  \
# 2108                        Edward Scissorhands          7.5        3601
# 1967                            The Fisher King          7.2         341
# 1695                                    Aladdin          7.4        3416
# 2790                               True Romance          7.5         749
# 809                                Forrest Gump          8.2        7927
# 556                                  Braveheart          7.7        3336
# 2661                             Romeo + Juliet          6.7        1374
# 25                                      Titanic          7.5        7562
# 407                              Meet Joe Black          6.9        1147
# 1120                               Notting Hill          7.0        1262
# 213                      Mission: Impossible II          5.9        1928
# 1260                                     Amélie          7.8        3310
# 159                                  Spider-Man          6.8        5265
# 423                              Bruce Almighty          6.4        3012
# 30                                 Spider-Man 2          6.7        4321
# 119                               Batman Begins          7.5        7359
# 2465                            Pan's Labyrinth          7.6        3041
# 113   Harry Potter and the Order of the Phoenix          7.4        5494
# 1337                                   Twilight          5.8        3561
# 0                                        Avatar          7.2       11800
# 96                                    Inception          8.1       13752
# 69                                         Hugo          7.0        2141
# 903                                         Ted          6.3        4697
# 506                             Despicable Me 2          7.0        4637
# 2838                     The Fault in Our Stars          7.6        3759
# 1599                         The Age of Adaline          7.4        1990
#
#       release_year
# 2108          1990
# 1967          1991
# 1695          1992
# 2790          1993
# 809           1994
# 556           1995
# 2661          1996
# 25            1997
# 407           1998
# 1120          1999
# 213           2000
# 1260          2001
# 159           2002
# 423           2003
# 30            2004
# 119           2005
# 2465          2006
# 113           2007
# 1337          2008
# 0             2009
# 96            2010
# 69            2011
# 903           2012
# 506           2013
# 2838          2014
# 1599          2015
#
# [26 rows x 21 columns]

# %%
## YOUR CODE HERE
## displaying the vote counts of defined 'love' movies every year using plyplot 
popular_lovemovies = love.loc[love.groupby('release_year')['vote_count'].idxmax()]
plt.rcParams.update({'font.size': 30})
plt.figure(figsize=(45, 75))
plt.rcParams.update({
    'font.size': 50,
    'axes.titlesize': 70,
    'axes.labelsize': 50,
    'xtick.labelsize': 50,
    'ytick.labelsize': 50,
    'legend.fontsize': 50
})

bar_width = 0.5
plt.bar(popular_lovemovies['release_year'] - bar_width / 2, popular_lovemovies['vote_count'], bar_width, color='maroon', label='Vote Count')
plt.xlabel('Year')
plt.ylabel('Amount of Votes')
plt.title('The Most Popular Voted Love Movies')

for i, row in popular_lovemovies.iterrows():
    plt.text(row['release_year'] - bar_width / 2, row['vote_count'], row['title'], ha='center', va='bottom', rotation=90)


plt.xticks(popular_lovemovies['release_year'], rotation=45)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# 1. **The Question:** Our question our group is trying to analyze is the relation between Romantic Comedies in film and Marriage and Divorce rates from 1990-2022 in the United States. This is why we are using The TMDb (The Movie Database) we found on Kaggle as well as the CDC's dataset released on Marriages and Divorces. We were interested in focusing on movies as our group enjoys film, specifically movies that contain the key words 'romance', 'love', 'fate', 'humor', 'meet cute', 'chemistry', 'heartwarming', 'feel good', 'relationships', and 'laughter' to signify the genre of a 'romantic comedy'. This question will track each movie’s financial budget, profit, audience rating, as well as genre to see if there is any correlation between romantic comedies and if there was an increase or decrease of marriages or divorces by year.
#
# 2. **The Implications:** The stakeholders for this questions would be the movie studios as we would create a tool to allow them to green light or forgo certain movie genres or scripts that they may be thinking about releasing. Some unintended consequences could be that after our final analysis we could find that Romantic Comedies are in fact linked to more Marriages which can lead the movies studios to release more or less depending on if they want the marriage rates to increase or decrease. This can become a detriment to writers, actors or directors as the movie studios would focus on movies or genres that only make them money rather than taking a chance on a movie ideas or scripts that are both original and innovating but may be less financially successful. Another implication would be that creativity would be stifled as the movie studios prioritize financial gains rather than take creative risks.
#
# 3. **The Data:** The dataset that we are using is available on Kaggle which contains over 1 million movie titles. Their dataset is also uploaded daily which means that there is always a consistent stream of data being created and used. There are also around 24 columns that we will be able to use to analyze so our data will be able to compare different aspects of the successful or failure of each movie. The only main bias we would have to be hesitant in using would be the voter’s rating and the total voter’s count of each movie. Since the dataset takes the average of the rating of each movie given by the viewer it may be skewed data as not every viewer who watches a movie will give a movie a rating. We would have to take into account that the audience of who is actually rating the movies are those who are very interested in movies and will take the time to rate a movie they just watched rather than just casual viewers who may not review a movie they just watched. For the Marriage and Divorce datasets, it is only broken up by states so we do not have detailed information on what race, age or what the individuals financial status are
#
# 4. **Informed Consent:** Since our datasets are all for public use and do not gather any of the individual’s personal information, there is no risk for using this dataset. All of the other empirical data regarding the movie’s budget and financial return are all available to the public so there is very low risk in using this dataset to answer our question. The other issue is if Kaggle or the owner of this dataset decides to remove this dataset, we wouldn’t be able to continue to use it anymore.
#
# 5. **Privacy:** Nothing we are using from these datasets will create any risks regarding privacy as this data was gathered from public sources such as IMDB. The main privacy issue would be the voter’s column but this specific dataset is anonymized which means that there is no identifiable information on who the voter actually is.
#
# 6. **Evaluation:** We will be able to evaluate our project after implementing a system to see if there is any pattern or correlation between highly successful romantic comedies during a specific year and if there was an increase of marriages or divorces. We will also take into account that if our outcome is not verifiable and that we see no patterns within the genre of romantic comedies we will have to make a conclusion based on that as well.
#
# 7. **Analysis:** We will need to spend time with our dataset to make sure that we are not just inferring things that do not correlate with each other. Taking into account financial success, audience ratings, and previous decades of movies being remade we will need to see empirical evidence in whether or not there is a pattern that the movie studios take when deciding if romantic comedies hold enough weight in persuading or dissuading individuals to get married.
#
# 8. **Transparency and Appeal:** Our model would not be a black box model as we have the empirical data to back up our findings. Since all of our data is publicly available we would not be able to alter the numbers such as financial gain and profit. We also have each film’s budget which we will take into account when it comes to a movie’s true profitability or not. The data is transparent in the way that the data gathered can be found online and not based on our own personal biases or inferences.
#
# 9. **Continuous Monitoring:** We will be able to update our metrics as the dataset that we are using is constantly being updated. Once we configure a good system and code in order to to use and analyze this data we would be able to use it until the dataset is removed from Kaggle. We will be weary of potential unintended side effects such as if movie studios want to use our system to analyze the the future trends of the popularity of romantic comedies and whether or not people will more or less likely marry during a year where the top grossing movies were romance based.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# Our group came to the consensus that in order to be successful in the completion of our project, we must hold ourselves and each other accountable in following the expectations we put in place.
#
# * *Team Expectation 1:* Effective Communication: Communicate when things need to be completed so that we are able to maintain consistent progress. We will communicate through messages and discord to share our ideas.
#
# * *Team Expectation 2:* Weekly Meetings: Show up to every weekly meeting so we can touch base on the progress of our project. We will meet every Thursday at 11 am (time that we all agree on) on a video call to work together and discuss our progress
#
# * *Team Expectation 3:* Asking Questions: Reach out and give each other the support when things begin to feel stressful. We will text any questions to the group chat for anyone to answer. We can also save any major questions that need further discussion for the video call meetings.
#
# * *Team Expectation 4:* Meeting Deadlines: Deadlines are important so make sure each individual's assigned portion is completed on time. We must set soft deadlines for specific parts of the project and all agree to complete our respective parts by the selected date.
#
# * *Team Expectation 5:* Checking Work: We should check each other’s work as we progress with the project to make sure we don’t have any errors. Be open to changes if necessary.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 4/25  |  11 AM | Create a Discord group chat to communicate | Get to know each other, brainstorm different topics and vote by next meeting date |
# | 5/2  |  11 AM |  Choose topic and gather information about the topic to present | Draft project proposal |
# | 5/9  | 11 AM  |  Everyone provides datasets they have searched for prior (Genre and box office sales)  | Assign group members to their part and discuss any questions/confusions   |
# | 5/16  | 11 AM  | Have data prepared and ready for the Checkpoint | Present the started work and review/edit together |
# | 5/23  | 11 AM  | Prepare for the next checkpoint | Work on EDA and edit together for the checkpoint |
# | 5/30  | 11 AM  | Complete EDA Checkpoint and have it ready to be reviewed | Start finalizing the final project and prepare additional information |
# | 6/6  | 11 AM  | Review the Final Project | Add final touch ups before turning the project in on 6/12 |
